# %% [markdown]
# # Concept Drift in a real dataset

# %% [markdown]
# INSECTS Dataset - Aplicação Real com Concept Drift
#
#
# O dataset é originado de um sistema de armadilhas eletrônicas inteligentes que usam sensores ópticos para:
#
# - Detectar em tempo real a passagem de insetos voadores,
#
# - Classificar a espécie do inseto usando aprendizado de máquina,
#
# - Capturar seletivamente apenas espécies de interesse (ex: mosquitos transmissores de doenças ou pragas agrícolas).

# %% [markdown]
# ![Imagem de uma armadilha eletrônica para insetos](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQTFdbomhwDVpnPylE8Jt6j5DW06WcVdUoeoQ&s)

# %% [markdown]
# ### Desenvolvimento e Contexto
#
# Este sistema foi desenvolvido por um grupo de pesquisa com foco em controle ambiental e agrícola. Ele utiliza sensores físicos, como sensores ópticos ou acústicos, para capturar sinais dos insetos. Com base nesses sinais, o sistema toma decisões em tempo real sobre capturar ou liberar os insetos, contribuindo para a redução do impacto ambiental ao liberar espécies que não são alvos.
#
# Desenvolvido por um grupo de pesquisa no contexto de controle ambiental e agrícola, envolve sensores físicos que captam sinais (possivelmente ópticos ou acústicos). O sistema toma decisões em tempo real sobre capturar ou liberar o inseto, reduz o impacto ambiental ao liberar insetos que não são alvos.
#
# Como o comportamento dos insetos e o ambiente podem variar com o tempo, clima, localidade, ou estação, o sistema precisa lidar com:
#
# - Mudança nos padrões dos dados de entrada (ex: diferentes voos ou espécies ao longo do dia),
#
# - Mudança no conceito de classificação (ex: variação no padrão de uma espécie por estação do ano).
#
# - Este é um caso real em que a detecção de drift de conceito é essencial para manter a acurácia e a eficiência ambiental do sistema ao longo do tempo.

# %% [markdown]
# Padrão de comportamento durante o dia de uma espécie de mosquito:

# %% [markdown]
# ![Imagem de uma armadilha eletrônica para insetos](/home/guilherme/Downloads/drift_vs/graph_insects.png)

# %% [markdown]
# O conjunto de dados contém atributos numéricos derivados de sinais ópticos (ex.: intensidade de reflexão, frequência de batimento de asas, tamanho estimado).
#
#
#
# O dataset contém 6 classes balanceadas, representando espécies fictícias (mas plausíveis) de insetos voadores:
#
# - Aedes communis (simula um mosquito)
#
# - Bombus terrestis (simula um zangão)
#
# - Culex pipiens (simula outro mosquito)
#
# - Drosophila melanogaster (mosca-da-fruta)
#
# - Ephemera vulgata (efêmera)
#
# - Harmonia axyridis (joaninha)

# %%
# Step 1: Import libraries
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score

# Step 2: Load the dataset
df = pd.read_csv('INSECTS-incremental_balanced_norm.csv')

# %%
df["Class"].value_counts()
# Out:
# Class
# 3.0    5903
# 5.0    5900
# 4.0    5898
# 2.0    5898
# 0.0    5893
# 1.0    5893
# Name: count, dtype: int64

# %%
# Step 3: Split into features and labels
X = df.drop('Class', axis=1)

y = df['Class']

N=1000

#Step 4: Split into training and test sets
X_train = X.iloc[:N]
y_train = y.iloc[:N]

X_test = X.iloc[N:]
y_test = y.iloc[N:]

# %%
y_train.value_counts()
# Out:
# Class
# 5.0    168
# 0.0    167
# 3.0    167
# 4.0    167
# 2.0    166
# 1.0    165
# Name: count, dtype: int64

# %% [markdown]
# ##  Computando a eficácia do método (usando o treinamento de tamanho N)

# %%
accuracies = []
f1_scores = []
window_size = 100

true_labels = []
predicted_labels = []

# # Step 5: Train Random Forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)


for i in range(len(X_test)):
    x_i = X_test.iloc[i:i+1]
    y_i = y_test.iloc[i:i+1].values[0]

    pred = rf.predict(x_i)[0]

    true_labels.append(y_i)
    predicted_labels.append(pred)

    # At end of each window, calculate metrics
    if (i + 1) % window_size == 0:

        f1 = f1_score(true_labels, predicted_labels, average='macro')
        #print(i, "f1 score: ", f1)
        f1_scores.append(f1)


        true_labels = []
        predicted_labels = []

        # if i > 10000:
        #     break
# Step 7: Plot accuracy and F1 score
plt.figure(figsize=(12, 5))


plt.subplot(1, 2, 2)
plt.plot(range(1, len(f1_scores) + 1), f1_scores, marker='o', color='green')
plt.xlabel(f'Window (each {window_size} instances)')
plt.ylabel('F1 Score (weighted)')
plt.title('Online F1 Score Over Time')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Retreinar o modelo

# %%
# # Step 5: Train Random Forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
accuracies = []
f1_scores = []
window_size = 10000

true_labels = []
predicted_labels = []

for i in range(len(X_test)):
    x_i = X_test.iloc[i:i+1]
    y_i = y_test.iloc[i:i+1].values[0]

    pred = rf.predict(x_i)[0]

    true_labels.append(y_i)
    predicted_labels.append(pred)

    # At end of each window, calculate metrics
    if (i + 1) % window_size == 0:

        f1 = f1_score(true_labels, predicted_labels, average='macro')

        f1_scores.append(f1)
        print(i, "f1 score: ", f1)

        # if i > 10000:
        #     break
        true_labels = []
        predicted_labels = []

# Step 7: Plot accuracy and F1 score
plt.figure(figsize=(12, 5))


plt.subplot(1, 2, 2)
plt.plot(range(1, len(f1_scores) + 1), f1_scores, marker='o', color='green')
plt.xlabel(f'Window (each {window_size} instances)')
plt.ylabel('F1 Score (weighted)')
plt.title('Online F1 Score Over Time')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# 9999 f1 score:  0.32075449307322207
# 19999 f1 score:  0.0914679088337375
# 29999 f1 score:  0.0599069032212455

# %% [markdown]
# # Tarefa

# %% [markdown]
# O objetivo desta atividade é evitar que tenha uma queda na qualidade da predição gerando o retreinamento do modelo de tempos em tempos. Para isso, deve-se monitorar a eficiência (f1), se estiver abaixo de um limiar deve-se rodar um retreino do modelo.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score

# =======================
# CONFIGURAÇÕES INICIAIS
# =======================

# Parâmetros
window_size = 1000           # Janela de avaliação
threshold = 0.8              # Limiar para retreinamento
N = 1000                     # Tamanho do conjunto inicial de treino

# ==========================
# CARREGAMENTO DO DATASET
# ==========================

df = pd.read_csv('INSECTS-incremental_balanced_norm.csv')
X = df.drop('Class', axis=1)
y = df['Class']

X_train = X.iloc[:N]
y_train = y.iloc[:N]
X_test = X.iloc[N:]
y_test = y.iloc[N:]

# =====================
# MODELOS A SEREM TESTADOS
# =====================

models = {
    'Random Forest': RandomForestClassifier(n_estimators=100, random_state=42),
    'SVM': SVC()
}

# Armazenar resultados
metrics_history = {name: {
    'f1': [], 'accuracy': [], 'precision': [], 'recall': [],
    'retrain_indices': []
} for name in models}

# ======================
# AVALIAÇÃO ADAPTATIVA
# ======================

for name, model in models.items():
    print(f"\n▶️ Avaliando modelo: {name}")
    model.fit(X_train, y_train)

    true_labels = []
    predicted_labels = []

    for i in range(len(X_test)):
        x_i = X_test.iloc[i:i+1]
        y_i = y_test.iloc[i:i+1].values[0]

        pred = model.predict(x_i)[0]
        predicted_labels.append(pred)
        true_labels.append(y_i)

        # Ao final de cada janela, avalia desempenho
        if (i + 1) % window_size == 0:
            f1 = f1_score(true_labels, predicted_labels, average='macro')
            acc = accuracy_score(true_labels, predicted_labels)
            prec = precision_score(true_labels, predicted_labels, average='macro')
            rec = recall_score(true_labels, predicted_labels, average='macro')

            metrics_history[name]['f1'].append(f1)
            metrics_history[name]['accuracy'].append(acc)
            metrics_history[name]['precision'].append(prec)
            metrics_history[name]['recall'].append(rec)

            print(f"Janela {i+1}: F1 = {f1:.4f} | Acc = {acc:.4f} | Prec = {prec:.4f} | Recall = {rec:.4f}")

            # Verifica necessidade de retreinamento
            if f1 < threshold:
                print("⚠️ Retreinamento necessário...")
                start_idx = i + 1 - window_size
                X_recent = X_test.iloc[start_idx:i+1]
                y_recent = y_test.iloc[start_idx:i+1]
                model.fit(X_recent, y_recent)
                metrics_history[name]['retrain_indices'].append(len(metrics_history[name]['f1']))

            true_labels = []
            predicted_labels = []

# ===========================
# VISUALIZAÇÃO DAS MÉTRICAS
# ===========================

fig, axs = plt.subplots(2, 2, figsize=(14, 8))
metric_names = ['f1', 'accuracy', 'precision', 'recall']
titles = ['F1 Score', 'Accuracy', 'Precision', 'Recall']

for ax, metric, title in zip(axs.flat, metric_names, titles):
    for name in models:
        ax.plot(metrics_history[name][metric], marker='o', label=name)
        # Marcar os pontos onde houve retreinamento
        for retrain_idx in metrics_history[name]['retrain_indices']:
            ax.axvline(x=retrain_idx - 1, linestyle='--', alpha=0.3)
    ax.set_title(title)
    ax.set_xlabel(f'Janela (cada {window_size} instâncias)')
    ax.set_ylabel(metric.capitalize())
    ax.legend()
    ax.grid(True)

plt.suptitle("Comparação de Modelos com Retreinamento Adaptativo", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# ▶️ Avaliando modelo: Random Forest
# Janela 1000: F1 = 0.4418 | Acc = 0.4500 | Prec = 0.4826 | Recall = 0.4494
# ⚠️ Retreinamento necessário...
# Janela 2000: F1 = 0.6178 | Acc = 0.6320 | Prec = 0.6219 | Recall = 0.6312
# ⚠️ Retreinamento necessário...
# Janela 3000: F1 = 0.6383 | Acc = 0.6430 | Prec = 0.6381 | Recall = 0.6439
# ⚠️ Retreinamento necessário...
# Janela 4000: F1 = 0.5975 | Acc = 0.6030 | Prec = 0.5967 | Recall = 0.6038
# ⚠️ Retreinamento necessário...
# Janela 5000: F1 = 0.5628 | Acc = 0.5680 | Prec = 0.5610 | Recall = 0.5673
# ⚠️ Retreinamento necessário...
# Janela 6000: F1 = 0.5237 | Acc = 0.5180 | Prec = 0.5346 | Recall = 0.5195
# ⚠️ Retreinamento necessário...
# Janela 7000: F1 = 0.6048 | Acc = 0.6090 | Prec = 0.6055 | Recall = 0.6076
# ⚠️ Retreinamento necessário...
# Janela 8000: F1 = 0.6143 | Acc = 0.6170 | Prec = 0.6153 | Recall = 0.6171
# ⚠️ Retreinamento necessário...
# Janela 9000: F1 = 0.5701 | Acc = 0.5690 | Prec = 0.5778 | Recall = 0.5704
# ⚠️ Retreinamento necessário...
# Janela 10000: F1 = 0.6396 | Acc = 0.6460 | Prec = 0.6420 | Recall = 0.6456
# ⚠️ Retreinamento necessário...
# Janela 11000: F1 = 0.5846 | Acc = 0.5900 | Prec = 0.5831 | Recall = 0.5893
# ⚠️ Retreinamento necessário...
# Janela 12000: F1 = 0.6114 | Acc = 0.6130 | Prec = 0.6196 | Recall = 0.6126
# ⚠️ Retreinamento necessário...
# Janela 13000: F1 = 0.6373 | Acc = 0.6460 | Prec = 0.6385 | Recall = 0.6478
# ⚠️ Retreinamento necessário...
# Janela 14000: F1 = 0.6378 | Acc = 0.6390 | Prec = 0.6377 | Recall = 0.6395
# ⚠️ Retreinamento necessário...
# Janela 15000: F1 = 0.5983 | Acc = 0.6000 | Prec = 0.6004 | Recall = 0.5998
# ⚠️ Retreinamento necessário...
# Janela 16000: F1 = 0.6341 | Acc = 0.6360 | Prec = 0.6338 | Recall = 0.6348
# ⚠️ Retreinamento necessário...
# Janela 17000: F1 = 0.6522 | Acc = 0.6580 | Prec = 0.6515 | Recall = 0.6588
# ⚠️ Retreinamento necessário...
# Janela 18000: F1 = 0.6440 | Acc = 0.6510 | Prec = 0.6437 | Recall = 0.6511
# ⚠️ Retreinamento necessário...
# Janela 19000: F1 = 0.6514 | Acc = 0.6540 | Prec = 0.6514 | Recall = 0.6544
# ⚠️ Retreinamento necessário...
# Janela 20000: F1 = 0.6338 | Acc = 0.6350 | Prec = 0.6379 | Recall = 0.6346
# ⚠️ Retreinamento necessário...
# Janela 21000: F1 = 0.6582 | Acc = 0.6610 | Prec = 0.6588 | Recall = 0.6617
# ⚠️ Retreinamento necessário...
# Janela 22000: F1 = 0.6929 | Acc = 0.6960 | Prec = 0.6906 | Recall = 0.6967
# ⚠️ Retreinamento necessário...
# Janela 23000: F1 = 0.6643 | Acc = 0.6710 | Prec = 0.6613 | Recall = 0.6698
# ⚠️ Retreinamento necessário...
# Janela 24000: F1 = 0.6171 | Acc = 0.6180 | Prec = 0.6323 | Recall = 0.6177
# ⚠️ Retreinamento necessário...
# Janela 25000: F1 = 0.6588 | Acc = 0.6610 | Prec = 0.6602 | Recall = 0.6601
# ⚠️ Retreinamento necessário...
# Janela 26000: F1 = 0.6913 | Acc = 0.6910 | Prec = 0.6917 | Recall = 0.6924
# ⚠️ Retreinamento necessário...
# Janela 27000: F1 = 0.6431 | Acc = 0.6440 | Prec = 0.6460 | Recall = 0.6436
# ⚠️ Retreinamento necessário...
# Janela 28000: F1 = 0.6664 | Acc = 0.6690 | Prec = 0.6681 | Recall = 0.6692
# ⚠️ Retreinamento necessário...
# Janela 29000: F1 = 0.6712 | Acc = 0.6750 | Prec = 0.6715 | Recall = 0.6743
# ⚠️ Retreinamento necessário...
# Janela 30000: F1 = 0.6308 | Acc = 0.6340 | Prec = 0.6319 | Recall = 0.6341
# ⚠️ Retreinamento necessário...
# Janela 31000: F1 = 0.6564 | Acc = 0.6560 | Prec = 0.6575 | Recall = 0.6573
# ⚠️ Retreinamento necessário...
# Janela 32000: F1 = 0.6493 | Acc = 0.6530 | Prec = 0.6497 | Recall = 0.6516
# ⚠️ Retreinamento necessário...
# Janela 33000: F1 = 0.6687 | Acc = 0.6700 | Prec = 0.6727 | Recall = 0.6700
# ⚠️ Retreinamento necessário...
# Janela 34000: F1 = 0.6534 | Acc = 0.6560 | Prec = 0.6542 | Recall = 0.6567
# ⚠️ Retreinamento necessário...
# Janela 35000: F1 = 0.6544 | Acc = 0.6550 | Prec = 0.6554 | Recall = 0.6550
# ⚠️ Retreinamento necessário...
# Janela 36000: F1 = 0.6410 | Acc = 0.6440 | Prec = 0.6413 | Recall = 0.6447
# ⚠️ Retreinamento necessário...
# Janela 37000: F1 = 0.6425 | Acc = 0.6410 | Prec = 0.6459 | Recall = 0.6413
# ⚠️ Retreinamento necessário...
# Janela 38000: F1 = 0.6375 | Acc = 0.6420 | Prec = 0.6415 | Recall = 0.6437
# ⚠️ Retreinamento necessário...
# Janela 39000: F1 = 0.6354 | Acc = 0.6380 | Prec = 0.6392 | Recall = 0.6378
# ⚠️ Retreinamento necessário...
# Janela 40000: F1 = 0.6587 | Acc = 0.6590 | Prec = 0.6606 | Recall = 0.6583
# ⚠️ Retreinamento necessário...
# Janela 41000: F1 = 0.7208 | Acc = 0.7200 | Prec = 0.7231 | Recall = 0.7198
# ⚠️ Retreinamento necessário...
# Janela 42000: F1 = 0.7077 | Acc = 0.7110 | Prec = 0.7111 | Recall = 0.7101
# ⚠️ Retreinamento necessário...
# Janela 43000: F1 = 0.7098 | Acc = 0.7140 | Prec = 0.7094 | Recall = 0.7125
# ⚠️ Retreinamento necessário...
# Janela 44000: F1 = 0.7202 | Acc = 0.7220 | Prec = 0.7232 | Recall = 0.7232
# ⚠️ Retreinamento necessário...
# Janela 45000: F1 = 0.7247 | Acc = 0.7280 | Prec = 0.7301 | Recall = 0.7262
# ⚠️ Retreinamento necessário...
# Janela 46000: F1 = 0.7232 | Acc = 0.7250 | Prec = 0.7250 | Recall = 0.7264
# ⚠️ Retreinamento necessário...
# Janela 47000: F1 = 0.7264 | Acc = 0.7260 | Prec = 0.7277 | Recall = 0.7261
# ⚠️ Retreinamento necessário...
# Janela 48000: F1 = 0.6950 | Acc = 0.6950 | Prec = 0.6973 | Recall = 0.6965
# ⚠️ Retreinamento necessário...
# Janela 49000: F1 = 0.7135 | Acc = 0.7150 | Prec = 0.7142 | Recall = 0.7149
# ⚠️ Retreinamento necessário...
# Janela 50000: F1 = 0.7194 | Acc = 0.7220 | Prec = 0.7188 | Recall = 0.7215
# ⚠️ Retreinamento necessário...
# Janela 51000: F1 = 0.6656 | Acc = 0.6680 | Prec = 0.6717 | Recall = 0.6701
# ⚠️ Retreinamento necessário...
# Janela 52000: F1 = 0.7208 | Acc = 0.7220 | Prec = 0.7232 | Recall = 0.7215
# ⚠️ Retreinamento necessário...
# Janela 53000: F1 = 0.7170 | Acc = 0.7170 | Prec = 0.7160 | Recall = 0.7187
# ⚠️ Retreinamento necessário...
# Janela 54000: F1 = 0.7178 | Acc = 0.7190 | Prec = 0.7197 | Recall = 0.7174
# ⚠️ Retreinamento necessário...
# Janela 55000: F1 = 0.6606 | Acc = 0.6600 | Prec = 0.6614 | Recall = 0.6614
# ⚠️ Retreinamento necessário...
# Janela 56000: F1 = 0.6905 | Acc = 0.6950 | Prec = 0.6940 | Recall = 0.6932
# ⚠️ Retreinamento necessário...
#
# ▶️ Avaliando modelo: SVM
# Janela 1000: F1 = 0.4308 | Acc = 0.4450 | Prec = 0.4514 | Recall = 0.4442
# ⚠️ Retreinamento necessário...
# Janela 2000: F1 = 0.5994 | Acc = 0.6220 | Prec = 0.6165 | Recall = 0.6207
# ⚠️ Retreinamento necessário...
# Janela 3000: F1 = 0.6146 | Acc = 0.6290 | Prec = 0.6171 | Recall = 0.6306
# ⚠️ Retreinamento necessário...
# Janela 4000: F1 = 0.5772 | Acc = 0.5840 | Prec = 0.5791 | Recall = 0.5844
# ⚠️ Retreinamento necessário...
# Janela 5000: F1 = 0.5627 | Acc = 0.5830 | Prec = 0.5682 | Recall = 0.5824
# ⚠️ Retreinamento necessário...
# Janela 6000: F1 = 0.5153 | Acc = 0.5310 | Prec = 0.5290 | Recall = 0.5343
# ⚠️ Retreinamento necessário...
# Janela 7000: F1 = 0.5407 | Acc = 0.5550 | Prec = 0.5436 | Recall = 0.5527
# ⚠️ Retreinamento necessário...
# Janela 8000: F1 = 0.6071 | Acc = 0.6170 | Prec = 0.6161 | Recall = 0.6173
# ⚠️ Retreinamento necessário...
# Janela 9000: F1 = 0.5774 | Acc = 0.5870 | Prec = 0.5854 | Recall = 0.5895
# ⚠️ Retreinamento necessário...
# Janela 10000: F1 = 0.5993 | Acc = 0.6100 | Prec = 0.6023 | Recall = 0.6086
# ⚠️ Retreinamento necessário...
# Janela 11000: F1 = 0.5785 | Acc = 0.5880 | Prec = 0.5831 | Recall = 0.5873
# ⚠️ Retreinamento necessário...
# Janela 12000: F1 = 0.5404 | Acc = 0.5510 | Prec = 0.5542 | Recall = 0.5505
# ⚠️ Retreinamento necessário...
# Janela 13000: F1 = 0.6155 | Acc = 0.6250 | Prec = 0.6176 | Recall = 0.6267
# ⚠️ Retreinamento necessário...
# Janela 14000: F1 = 0.6169 | Acc = 0.6210 | Prec = 0.6187 | Recall = 0.6208
# ⚠️ Retreinamento necessário...
# Janela 15000: F1 = 0.5381 | Acc = 0.5460 | Prec = 0.5345 | Recall = 0.5460
# ⚠️ Retreinamento necessário...
# Janela 16000: F1 = 0.6134 | Acc = 0.6240 | Prec = 0.6171 | Recall = 0.6218
# ⚠️ Retreinamento necessário...
# Janela 17000: F1 = 0.6312 | Acc = 0.6400 | Prec = 0.6387 | Recall = 0.6409
# ⚠️ Retreinamento necessário...
# Janela 18000: F1 = 0.5871 | Acc = 0.5950 | Prec = 0.5848 | Recall = 0.5951
# ⚠️ Retreinamento necessário...
# Janela 19000: F1 = 0.6313 | Acc = 0.6400 | Prec = 0.6344 | Recall = 0.6409
# ⚠️ Retreinamento necessário...
# Janela 20000: F1 = 0.6193 | Acc = 0.6190 | Prec = 0.6275 | Recall = 0.6181
# ⚠️ Retreinamento necessário...
# Janela 21000: F1 = 0.6213 | Acc = 0.6340 | Prec = 0.6213 | Recall = 0.6353
# ⚠️ Retreinamento necessário...
# Janela 22000: F1 = 0.6404 | Acc = 0.6450 | Prec = 0.6388 | Recall = 0.6457
# ⚠️ Retreinamento necessário...
# Janela 23000: F1 = 0.6306 | Acc = 0.6460 | Prec = 0.6276 | Recall = 0.6445
# ⚠️ Retreinamento necessário...
# Janela 24000: F1 = 0.5683 | Acc = 0.5750 | Prec = 0.5704 | Recall = 0.5751
# ⚠️ Retreinamento necessário...
# Janela 25000: F1 = 0.6280 | Acc = 0.6310 | Prec = 0.6294 | Recall = 0.6300
# ⚠️ Retreinamento necessário...
# Janela 26000: F1 = 0.6417 | Acc = 0.6450 | Prec = 0.6437 | Recall = 0.6471
# ⚠️ Retreinamento necessário...
# Janela 27000: F1 = 0.6241 | Acc = 0.6290 | Prec = 0.6240 | Recall = 0.6282
# ⚠️ Retreinamento necessário...
# Janela 28000: F1 = 0.6374 | Acc = 0.6390 | Prec = 0.6402 | Recall = 0.6396
# ⚠️ Retreinamento necessário...
# Janela 29000: F1 = 0.6376 | Acc = 0.6400 | Prec = 0.6391 | Recall = 0.6387
# ⚠️ Retreinamento necessário...
# Janela 30000: F1 = 0.6153 | Acc = 0.6220 | Prec = 0.6189 | Recall = 0.6226
# ⚠️ Retreinamento necessário...
# Janela 31000: F1 = 0.6321 | Acc = 0.6420 | Prec = 0.6376 | Recall = 0.6430
# ⚠️ Retreinamento necessário...
# Janela 32000: F1 = 0.5953 | Acc = 0.6060 | Prec = 0.6032 | Recall = 0.6039
# ⚠️ Retreinamento necessário...
# Janela 33000: F1 = 0.6225 | Acc = 0.6260 | Prec = 0.6307 | Recall = 0.6268
# ⚠️ Retreinamento necessário...
# Janela 34000: F1 = 0.6176 | Acc = 0.6250 | Prec = 0.6259 | Recall = 0.6246
# ⚠️ Retreinamento necessário...
# Janela 35000: F1 = 0.6240 | Acc = 0.6280 | Prec = 0.6310 | Recall = 0.6280
# ⚠️ Retreinamento necessário...
# Janela 36000: F1 = 0.6161 | Acc = 0.6250 | Prec = 0.6201 | Recall = 0.6250
# ⚠️ Retreinamento necessário...
# Janela 37000: F1 = 0.6200 | Acc = 0.6230 | Prec = 0.6229 | Recall = 0.6225
# ⚠️ Retreinamento necessário...
# Janela 38000: F1 = 0.6071 | Acc = 0.6150 | Prec = 0.6135 | Recall = 0.6173
# ⚠️ Retreinamento necessário...
# Janela 39000: F1 = 0.6418 | Acc = 0.6440 | Prec = 0.6463 | Recall = 0.6444
# ⚠️ Retreinamento necessário...
# Janela 40000: F1 = 0.6426 | Acc = 0.6480 | Prec = 0.6525 | Recall = 0.6476
# ⚠️ Retreinamento necessário...
# Janela 41000: F1 = 0.7069 | Acc = 0.7080 | Prec = 0.7098 | Recall = 0.7078
# ⚠️ Retreinamento necessário...
# Janela 42000: F1 = 0.6827 | Acc = 0.6850 | Prec = 0.6881 | Recall = 0.6847
# ⚠️ Retreinamento necessário...
# Janela 43000: F1 = 0.6938 | Acc = 0.6970 | Prec = 0.6951 | Recall = 0.6956
# ⚠️ Retreinamento necessário...
# Janela 44000: F1 = 0.7049 | Acc = 0.7110 | Prec = 0.7133 | Recall = 0.7124
# ⚠️ Retreinamento necessário...
# Janela 45000: F1 = 0.7037 | Acc = 0.7100 | Prec = 0.7133 | Recall = 0.7075
# ⚠️ Retreinamento necessário...
# Janela 46000: F1 = 0.6920 | Acc = 0.6950 | Prec = 0.6932 | Recall = 0.6975
# ⚠️ Retreinamento necessário...
# Janela 47000: F1 = 0.6956 | Acc = 0.6960 | Prec = 0.7017 | Recall = 0.6967
# ⚠️ Retreinamento necessário...
# Janela 48000: F1 = 0.6883 | Acc = 0.6890 | Prec = 0.6899 | Recall = 0.6903
# ⚠️ Retreinamento necessário...
# Janela 49000: F1 = 0.6808 | Acc = 0.6840 | Prec = 0.6839 | Recall = 0.6847
# ⚠️ Retreinamento necessário...
# Janela 50000: F1 = 0.7034 | Acc = 0.7050 | Prec = 0.7042 | Recall = 0.7046
# ⚠️ Retreinamento necessário...
# Janela 51000: F1 = 0.6172 | Acc = 0.6260 | Prec = 0.6287 | Recall = 0.6284
# ⚠️ Retreinamento necessário...
# Janela 52000: F1 = 0.6916 | Acc = 0.6970 | Prec = 0.6930 | Recall = 0.6968
# ⚠️ Retreinamento necessário...
# Janela 53000: F1 = 0.6964 | Acc = 0.7010 | Prec = 0.6998 | Recall = 0.7024
# ⚠️ Retreinamento necessário...
# Janela 54000: F1 = 0.6743 | Acc = 0.6790 | Prec = 0.6752 | Recall = 0.6765
# ⚠️ Retreinamento necessário...
# Janela 55000: F1 = 0.5915 | Acc = 0.5930 | Prec = 0.5994 | Recall = 0.5944
# ⚠️ Retreinamento necessário...
# Janela 56000: F1 = 0.6548 | Acc = 0.6620 | Prec = 0.6611 | Recall = 0.6604
# ⚠️ Retreinamento necessário...
